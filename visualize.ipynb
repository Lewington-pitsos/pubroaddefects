# %% [markdown]
# # Example Image Visualization
#
# This repository also includes some very basic code for making it easier to view raw annotated images, assuming they are stored in the required format.

# %%
import matplotlib.pyplot as plt

from app.glob import *
from app.graph import with_boxes

# %%
_, ax = plt.subplots(figsize=(20, 20))

ax.imshow(with_boxes("data/train/Czech/images/Czech_000121.jpg"))

# %% [markdown]
# And again with proper names rather than defect codes:

# %%
_, ax = plt.subplots(figsize=(20, 20))

ax.imshow(with_boxes("data/train/Japan/images/Japan_000072.jpg", mapping=COMMON_DEFECTS_MAP))
